# %% [markdown]
# # copyright: Jagadeesh Vasudevamurthy
# # Frie:  Friends.ipynb

# %% [markdown]
# # WRITE CODE ONLY IN THIS CELL

# %%
############################################################
# Solution.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
# All imports
###########################################################
# from Util import *

class Solution:
  def __init__(self,n:'int',a:'list of size 2'):
    self._n = n
    #a[0] = How many friends are there in n. Use _increment_number_of_friends to fill
    #a[1] = num_steps Use _increment_steps
    self._list = a
    ##YOU CAN HAVE ANY NUMBER OF DATA STRUCTURES HERE
    self._u = Util()
    self._sqrt=self._u.sqrt_upper_bound
    

    ## NOTHING CAN BE CHANGED BELOW
    self._alg()

  def _increment_steps(self)->'none':
    self._list[1] = self._list[1] + 1

  def _increment_number_of_friends(self)->"int":
    self._list[0] = self._list[0] + 1
    return (self._list[0])


  ##Implement your code BELOW
  ##You can have any number of private variables and functions

  def _alg(self):
    print("WRITE CODE")
    print("Write as many small functions as possible")
    friends=[]
    
    #find prime list
    is_prime = [True]* self._n
    is_prime[0] =False
    is_prime[1] =False
    for i in range(2, int(self._n** 0.5) + 1):
      if is_prime[i]:
        for j in range(i * i, self._n, i):
          is_prime[j] = False
    primes=[i for i, prime in enumerate(is_prime) if prime]
    # print(primes[0],primes[1],primes[2],primes[3])
    
    
    
    #set a list to contain all the divisors of each number
    result=[None]*(self._n+1)
    for j in range(0, self._n+1):
      result[j]=1
    
    #all the divisors of each number are found
    #calculate the sum of divisors of each nnumber
    for i in range(2,self._n+1):
      self._increment_steps()
      b=2
      while(i*b<self._n+1):
        result[i*b]=result[i*b]+i
        b=b+1
    
   

    #check amicabe pairs
    seen=set()
    for m in range(0, self._n+1):
      self._increment_steps()
      a=result[m]
      if a<=self._n and result[a]==m and a!=m and m not in seen:
        #find pairs
        seen.add(m)
        seen.add(a)
        print(m, a)
        self._increment_number_of_friends()

# %% [markdown]
# # Some useful function
# # Can use if required

# %%
############################################################
# Util.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2020
###########################################################

############################################################
# NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################
import sys # For getting Python Version
import random 
import math
from time import process_time 

class Util():
  pass


  ############################################
  # log to the next possible integer
  #########################################
  def log_upper_bound(self, n:'int', b:'int')->'int':
    f = math.log(n,b)
    c = math.ceil(f)
    return c 

  ############################################
  # log to the smallest possible integer
  #########################################
  def log_lower_bound(self, n:'int', b:'int')->'int':
    f = math.log(n,b)
    c = math.floor(f)
    return c 

  ############################################
  # sqrt to the next possible integer
  #########################################
  def sqrt_upper_bound(self, n:'int')->'int':
    f = math.sqrt(n)
    c = math.ceil(f)
    return c

# %% [markdown]
# # TEST BENCH
# # NOTHING CAN BE CHANGED BELOW

# %%
############################################################
# Friends.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
#           NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################
#from Util import *
#from Solution import *


class Friends():
  def __init__(self):
    self._u = Util()
    self._testBench()

  def _testBench(self):
    self._tests()
    print("ALL TESTS PASSED")

  def _test1(self,n:'int',ans:'int'):
    print("-------------", n , "-------------------------")
    a = [0,0]
    t1_start = process_time()
    s = Solution(n,a) ##All action happens here
    t1_stop = process_time() 
    if (a[1] == 0):
        print("How did you solve the problem in 0 steps")
        print("when ever you loop call _increment_steps() ")
        assert(False)
    if (a[0] == 0):
        print("Number of friends is 0. How?")
        print("when ever you find friend call _increment_number_of_friends ")
        assert(False)
    d = t1_stop - t1_start; 
    print(n, " has ", a[0], " friends. Took", a[1], " steps to compute")
    print("Total CPU time in sec =",d)
    logn_base2 = self._u.log_lower_bound(n,2)
    nlogn = n * logn_base2
    w = a[1] / nlogn 
    print("n = ", n)
    print("logn ", logn_base2)
    print("nlogn ",nlogn)
    print("num_steps/nlogn", w)
    if (a[0] != ans):
      print(n," Has", ans, "Friends. But you are telling",a[0])
      assert(a[0] == ans)


  def _tests(self):
    n = 10000
    a = self._test1(n,5)

    n = 20000
    a = self._test1(n,8)

    # n = 300000
    # a = self._test1(n,22)

    # n = 1000000
    # a = self._test1(n, 40)

    # n = 10000000
    # a = self._test1(n, 100)

    n = 100000000 ## YOU CANNOT CHANGE THIS.
    a = self._test1(n,231)


############################################################
# main 
# YOU CANNOT CHANGE ANYTHING BELOW
###########################################################
def main():
  print("Testing Friends.py Starts")
  s = Friends()
  print("Testing Friends.py ENDS")

############################################################
# Pthin calls this
###########################################################
if (__name__  == '__main__'):
  main()
